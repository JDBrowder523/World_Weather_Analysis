# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the Latitudes and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#print(url)

# %%
# Import the requests library.
#import requests

# Import the API key.
#from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Testing URL for city = Boston
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#city_url = url + "&q=" + "Boston"
#print(city_url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | manjacaze
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | clyde river
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | hasaki
# Processing Record 8 of Set 1 | tuatapere
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | kaitangata
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | golcuk
# City not found. Skipping...
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | isangel
# Processing Record 18 of Set 1 | simpang
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | faanui
# Processing Record 21 of Set 1 | kruisfontein
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | tilichiki
# Processing Record 25 of Set 1 | la asuncion
# Processing Record 26 of Set 1 | norfolk
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | aripuana
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | beregovoy
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 1 | korla
# Processing Record 34 of Set 1 | cabedelo
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | puerto del rosario
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | touros
# Processing Record 41 of Set 1 | coihueco
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | hohhot
# Processing Record 45 of Set 1 | caravelas
# Processing Record 46 of Set 1 | berbera
# Processing Record 47 of Set 1 | praia
# Processing Record 48 of Set 1 | karimganj
# Processing Record 49 of Set 1 | carlsbad
# Processing Record 50 of Set 1 | barcelos
# Processing Record 1 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | saint anthony
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | lompoc
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | baiyin
# Processing Record 17 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | mhlambanyatsi
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | san rafael
# Processing Record 22 of Set 2 | guipavas
# Processing Record 23 of Set 2 | san matias
# Processing Record 24 of Set 2 | avera
# Processing Record 25 of Set 2 | kuusankoski
# Processing Record 26 of Set 2 | upernavik
# Processing Record 27 of Set 2 | victoria
# Processing Record 28 of Set 2 | gizo
# Processing Record 29 of Set 2 | mayumba
# Processing Record 30 of Set 2 | naze
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | dingle
# Processing Record 33 of Set 2 | ilulissat
# Processing Record 34 of Set 2 | dahod
# Processing Record 35 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 2 | gualeguay
# Processing Record 37 of Set 2 | paamiut
# Processing Record 38 of Set 2 | bilibino
# Processing Record 39 of Set 2 | rensvik
# Processing Record 40 of Set 2 | qobustan
# Processing Record 41 of Set 2 | ponta do sol
# Processing Record 42 of Set 2 | santa cruz
# Processing Record 43 of Set 2 | mogadishu
# Processing Record 44 of Set 2 | tommot
# Processing Record 45 of Set 2 | kyren
# Processing Record 46 of Set 2 | walvis bay
# Processing Record 47 of Set 2 | san cristobal
# Processing Record 48 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 2 | nara
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 1 of Set 3 | atikokan
# Processing Record 2 of Set 3 | vaini
# Processing Record 3 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 4 of Set 3 | nylstroom
# City not found. Skipping...
# Processing Record 5 of Set 3 | geraldton
# Processing Record 6 of Set 3 | klaksvik
# Processing Record 7 of Set 3 | blagoyevo
# Processing Record 8 of Set 3 | vila franca do campo
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | katsuura
# Processing Record 11 of Set 3 | yellowknife
# Processing Record 12 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 13 of Set 3 | port macquarie
# Processing Record 14 of Set 3 | koosa
# Processing Record 15 of Set 3 | beringovskiy
# Processing Record 16 of Set 3 | billings
# Processing Record 17 of Set 3 | ostrovnoy
# Processing Record 18 of Set 3 | evensk
# Processing Record 19 of Set 3 | taltal
# Processing Record 20 of Set 3 | bolotnoye
# Processing Record 21 of Set 3 | mezen
# Processing Record 22 of Set 3 | zhigansk
# Processing Record 23 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 3 | hofn
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | cuencame
# Processing Record 27 of Set 3 | port blair
# Processing Record 28 of Set 3 | kashi
# Processing Record 29 of Set 3 | ahipara
# Processing Record 30 of Set 3 | imbituba
# Processing Record 31 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 3 | kholm-zhirkovskiy
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | merke
# Processing Record 35 of Set 3 | kavaratti
# Processing Record 36 of Set 3 | jamestown
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | namatanai
# Processing Record 39 of Set 3 | indianola
# Processing Record 40 of Set 3 | sangar
# Processing Record 41 of Set 3 | ercis
# Processing Record 42 of Set 3 | wawa
# Processing Record 43 of Set 3 | ambulu
# Processing Record 44 of Set 3 | vila velha
# Processing Record 45 of Set 3 | kavieng
# Processing Record 46 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 3 | coahuayana
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | darnah
# Processing Record 50 of Set 3 | kemijarvi
# Processing Record 1 of Set 4 | tupik
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | naro
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | pevek
# Processing Record 6 of Set 4 | hilo
# Processing Record 7 of Set 4 | bogorodskoye
# Processing Record 8 of Set 4 | malpe
# Processing Record 9 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 10 of Set 4 | potenza
# Processing Record 11 of Set 4 | mahebourg
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | yeppoon
# Processing Record 14 of Set 4 | margate
# Processing Record 15 of Set 4 | leh
# Processing Record 16 of Set 4 | cabra
# Processing Record 17 of Set 4 | iraucuba
# Processing Record 18 of Set 4 | vostok
# Processing Record 19 of Set 4 | alta floresta
# Processing Record 20 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 4 | naifaru
# Processing Record 22 of Set 4 | mayo
# Processing Record 23 of Set 4 | santa lucia
# Processing Record 24 of Set 4 | gweta
# Processing Record 25 of Set 4 | nemuro
# Processing Record 26 of Set 4 | tornio
# Processing Record 27 of Set 4 | marsa matruh
# Processing Record 28 of Set 4 | pacific grove
# Processing Record 29 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 4 | westport
# Processing Record 31 of Set 4 | smirnykh
# Processing Record 32 of Set 4 | wanning
# Processing Record 33 of Set 4 | muisne
# Processing Record 34 of Set 4 | beyneu
# Processing Record 35 of Set 4 | tura
# Processing Record 36 of Set 4 | hailar
# Processing Record 37 of Set 4 | akhmim
# Processing Record 38 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 4 | camopi
# Processing Record 40 of Set 4 | ternate
# Processing Record 41 of Set 4 | provideniya
# Processing Record 42 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 4 | conakry
# Processing Record 44 of Set 4 | bereda
# Processing Record 45 of Set 4 | plouzane
# Processing Record 46 of Set 4 | upata
# Processing Record 47 of Set 4 | lagoa
# Processing Record 48 of Set 4 | muros
# Processing Record 49 of Set 4 | ambilobe
# Processing Record 50 of Set 4 | monte alegre
# Processing Record 1 of Set 5 | muli
# Processing Record 2 of Set 5 | outjo
# Processing Record 3 of Set 5 | los llanos de aridane
# Processing Record 4 of Set 5 | pauini
# Processing Record 5 of Set 5 | yulara
# Processing Record 6 of Set 5 | puerto escondido
# Processing Record 7 of Set 5 | vysokopillya
# Processing Record 8 of Set 5 | mount isa
# Processing Record 9 of Set 5 | mugango
# Processing Record 10 of Set 5 | cap malheureux
# Processing Record 11 of Set 5 | vicuna
# Processing Record 12 of Set 5 | japura
# Processing Record 13 of Set 5 | aasiaat
# Processing Record 14 of Set 5 | pangnirtung
# Processing Record 15 of Set 5 | nome
# Processing Record 16 of Set 5 | iqaluit
# Processing Record 17 of Set 5 | batemans bay
# Processing Record 18 of Set 5 | serenje
# Processing Record 19 of Set 5 | constitucion
# Processing Record 20 of Set 5 | micheweni
# Processing Record 21 of Set 5 | liepaja
# Processing Record 22 of Set 5 | kaseda
# Processing Record 23 of Set 5 | frederico westphalen
# Processing Record 24 of Set 5 | tiarei
# Processing Record 25 of Set 5 | ketchikan
# Processing Record 26 of Set 5 | leningradskiy
# Processing Record 27 of Set 5 | chapais
# Processing Record 28 of Set 5 | labuhan
# Processing Record 29 of Set 5 | matara
# Processing Record 30 of Set 5 | roald
# Processing Record 31 of Set 5 | bintulu
# Processing Record 32 of Set 5 | bandarbeyla
# Processing Record 33 of Set 5 | sampit
# Processing Record 34 of Set 5 | cam pha
# City not found. Skipping...
# Processing Record 35 of Set 5 | te anau
# Processing Record 36 of Set 5 | buston
# Processing Record 37 of Set 5 | makushino
# Processing Record 38 of Set 5 | mount gambier
# Processing Record 39 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 5 | fez
# Processing Record 41 of Set 5 | bubaque
# Processing Record 42 of Set 5 | marienburg
# Processing Record 43 of Set 5 | gwadar
# Processing Record 44 of Set 5 | sibolga
# Processing Record 45 of Set 5 | cayenne
# Processing Record 46 of Set 5 | coihaique
# Processing Record 47 of Set 5 | anchorage
# Processing Record 48 of Set 5 | tasiilaq
# Processing Record 49 of Set 5 | esperance
# Processing Record 50 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 1 of Set 6 | bengkulu
# Processing Record 2 of Set 6 | kenai
# Processing Record 3 of Set 6 | taicheng
# Processing Record 4 of Set 6 | port augusta
# Processing Record 5 of Set 6 | lozuvatka
# Processing Record 6 of Set 6 | north bend
# Processing Record 7 of Set 6 | bambous virieux
# Processing Record 8 of Set 6 | tergnier
# Processing Record 9 of Set 6 | kibala
# Processing Record 10 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 6 | namibe
# Processing Record 12 of Set 6 | sao gabriel da cachoeira
# Processing Record 13 of Set 6 | bol
# Processing Record 14 of Set 6 | ozinki
# Processing Record 15 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 6 | torbay
# Processing Record 17 of Set 6 | chihuahua
# Processing Record 18 of Set 6 | houma
# Processing Record 19 of Set 6 | terrace
# Processing Record 20 of Set 6 | poum
# Processing Record 21 of Set 6 | yerbogachen
# Processing Record 22 of Set 6 | mathbaria
# Processing Record 23 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 24 of Set 6 | obo
# Processing Record 25 of Set 6 | yar-sale
# Processing Record 26 of Set 6 | severo-kurilsk
# Processing Record 27 of Set 6 | nouadhibou
# Processing Record 28 of Set 6 | nalut
# Processing Record 29 of Set 6 | praia da vitoria
# Processing Record 30 of Set 6 | saint-pierre
# Processing Record 31 of Set 6 | ancud
# Processing Record 32 of Set 6 | nizwa
# Processing Record 33 of Set 6 | sawtell
# Processing Record 34 of Set 6 | sao filipe
# Processing Record 35 of Set 6 | keti bandar
# Processing Record 36 of Set 6 | fairbanks
# Processing Record 37 of Set 6 | codrington
# Processing Record 38 of Set 6 | jinchang
# Processing Record 39 of Set 6 | zeya
# Processing Record 40 of Set 6 | adrar
# Processing Record 41 of Set 6 | den helder
# Processing Record 42 of Set 6 | cabo san lucas
# Processing Record 43 of Set 6 | yarim
# Processing Record 44 of Set 6 | noumea
# Processing Record 45 of Set 6 | madang
# Processing Record 46 of Set 6 | french harbor
# Processing Record 47 of Set 6 | kahului
# Processing Record 48 of Set 6 | sao paulo de olivenca
# Processing Record 49 of Set 6 | arbroath
# Processing Record 50 of Set 6 | manzhouli
# Processing Record 1 of Set 7 | fortuna
# Processing Record 2 of Set 7 | shatalovo
# Processing Record 3 of Set 7 | point fortin
# Processing Record 4 of Set 7 | egvekinot
# Processing Record 5 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 7 | ramgarh
# Processing Record 7 of Set 7 | luga
# Processing Record 8 of Set 7 | talnakh
# Processing Record 9 of Set 7 | catio
# Processing Record 10 of Set 7 | daru
# Processing Record 11 of Set 7 | oussouye
# Processing Record 12 of Set 7 | gao
# Processing Record 13 of Set 7 | andrelandia
# Processing Record 14 of Set 7 | christchurch
# Processing Record 15 of Set 7 | grand-santi
# Processing Record 16 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 7 | poya
# Processing Record 18 of Set 7 | atar
# Processing Record 19 of Set 7 | invermere
# Processing Record 20 of Set 7 | zhigalovo
# Processing Record 21 of Set 7 | gravelbourg
# Processing Record 22 of Set 7 | marawi
# Processing Record 23 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 7 | bykivka
# Processing Record 25 of Set 7 | havelock
# Processing Record 26 of Set 7 | guzelyurt
# Processing Record 27 of Set 7 | sola
# Processing Record 28 of Set 7 | peterhead
# Processing Record 29 of Set 7 | olafsvik
# Processing Record 30 of Set 7 | arona
# Processing Record 31 of Set 7 | kayes
# Processing Record 32 of Set 7 | pemangkat
# Processing Record 33 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 7 | norman wells
# Processing Record 35 of Set 7 | bathsheba
# Processing Record 36 of Set 7 | salalah
# Processing Record 37 of Set 7 | tsiroanomandidy
# Processing Record 38 of Set 7 | inuvik
# Processing Record 39 of Set 7 | hamilton
# Processing Record 40 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 7 | tiznit
# Processing Record 42 of Set 7 | penzance
# Processing Record 43 of Set 7 | grand gaube
# Processing Record 44 of Set 7 | acapulco
# Processing Record 45 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 7 | deta
# Processing Record 47 of Set 7 | mackay
# Processing Record 48 of Set 7 | itarema
# Processing Record 49 of Set 7 | bredy
# Processing Record 50 of Set 7 | alexandria
# Processing Record 1 of Set 8 | freeport
# Processing Record 2 of Set 8 | russell
# Processing Record 3 of Set 8 | nha trang
# Processing Record 4 of Set 8 | brae
# Processing Record 5 of Set 8 | asau
# Processing Record 6 of Set 8 | businga
# Processing Record 7 of Set 8 | bilma
# Processing Record 8 of Set 8 | lasa
# Processing Record 9 of Set 8 | port lincoln
# Processing Record 10 of Set 8 | vardo
# Processing Record 11 of Set 8 | tuy hoa
# Processing Record 12 of Set 8 | qasigiannguit
# Processing Record 13 of Set 8 | sherpur
# Processing Record 14 of Set 8 | bud
# Processing Record 15 of Set 8 | inyonga
# Processing Record 16 of Set 8 | kitui
# Processing Record 17 of Set 8 | bhuj
# Processing Record 18 of Set 8 | sohbatpur
# Processing Record 19 of Set 8 | deputatskiy
# Processing Record 20 of Set 8 | sioux lookout
# Processing Record 21 of Set 8 | santander
# Processing Record 22 of Set 8 | port-gentil
# Processing Record 23 of Set 8 | araouane
# Processing Record 24 of Set 8 | cardoso
# Processing Record 25 of Set 8 | ixtapa
# Processing Record 26 of Set 8 | youghal
# Processing Record 27 of Set 8 | amuntai
# Processing Record 28 of Set 8 | arraial do cabo
# Processing Record 29 of Set 8 | kathmandu
# Processing Record 30 of Set 8 | huntly
# Processing Record 31 of Set 8 | shingu
# Processing Record 32 of Set 8 | zmievka
# City not found. Skipping...
# Processing Record 33 of Set 8 | nanortalik
# Processing Record 34 of Set 8 | talara
# Processing Record 35 of Set 8 | hambantota
# Processing Record 36 of Set 8 | vestmanna
# Processing Record 37 of Set 8 | sabha
# Processing Record 38 of Set 8 | hobyo
# Processing Record 39 of Set 8 | komsomolskiy
# Processing Record 40 of Set 8 | iquique
# Processing Record 41 of Set 8 | mairi
# Processing Record 42 of Set 8 | san patricio
# Processing Record 43 of Set 8 | zhangjiakou
# Processing Record 44 of Set 8 | shubarkuduk
# Processing Record 45 of Set 8 | mabaruma
# Processing Record 46 of Set 8 | carbonia
# Processing Record 47 of Set 8 | ewa beach
# Processing Record 48 of Set 8 | ballina
# Processing Record 49 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 50 of Set 8 | alofi
# Processing Record 1 of Set 9 | xunchang
# Processing Record 2 of Set 9 | kamenka
# Processing Record 3 of Set 9 | cidreira
# Processing Record 4 of Set 9 | yatou
# Processing Record 5 of Set 9 | ishigaki
# Processing Record 6 of Set 9 | marsh harbour
# Processing Record 7 of Set 9 | harper
# Processing Record 8 of Set 9 | verkhnyaya inta
# Processing Record 9 of Set 9 | kosh-agach
# Processing Record 10 of Set 9 | juneau
# Processing Record 11 of Set 9 | shirokiy
# Processing Record 12 of Set 9 | bauta
# Processing Record 13 of Set 9 | itirucu
# Processing Record 14 of Set 9 | beloha
# Processing Record 15 of Set 9 | mango
# Processing Record 16 of Set 9 | baykit
# Processing Record 17 of Set 9 | cukai
# Processing Record 18 of Set 9 | verkhnevilyuysk
# Processing Record 19 of Set 9 | tazovskiy
# Processing Record 20 of Set 9 | dunedin
# Processing Record 21 of Set 9 | moussoro
# Processing Record 22 of Set 9 | kirakira
# Processing Record 23 of Set 9 | zaranj
# Processing Record 24 of Set 9 | marzuq
# Processing Record 25 of Set 9 | angoram
# Processing Record 26 of Set 9 | mudyuga
# City not found. Skipping...
# Processing Record 27 of Set 9 | laguna
# Processing Record 28 of Set 9 | takoradi
# Processing Record 29 of Set 9 | jeremie
# Processing Record 30 of Set 9 | okrika
# Processing Record 31 of Set 9 | san antonio
# Processing Record 32 of Set 9 | yuancheng
# Processing Record 33 of Set 9 | weiser
# Processing Record 34 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 9 | zhitikara
# City not found. Skipping...
# Processing Record 36 of Set 9 | corn island
# Processing Record 37 of Set 9 | itacare
# Processing Record 38 of Set 9 | grafton
# Processing Record 39 of Set 9 | abrau-dyurso
# Processing Record 40 of Set 9 | paso de los toros
# Processing Record 41 of Set 9 | chernyshevsk
# Processing Record 42 of Set 9 | tautira
# Processing Record 43 of Set 9 | chokwe
# Processing Record 44 of Set 9 | aviles
# Processing Record 45 of Set 9 | nautla
# Processing Record 46 of Set 9 | contai
# Processing Record 47 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 9 | sakakah
# Processing Record 49 of Set 9 | buraydah
# Processing Record 50 of Set 9 | jujuy
# City not found. Skipping...
# Processing Record 1 of Set 10 | zhuhai
# Processing Record 2 of Set 10 | miyako
# Processing Record 3 of Set 10 | tabuk
# Processing Record 4 of Set 10 | basco
# Processing Record 5 of Set 10 | bunia
# Processing Record 6 of Set 10 | lavrentiya
# Processing Record 7 of Set 10 | bonavista
# Processing Record 8 of Set 10 | chuy
# Processing Record 9 of Set 10 | sitka
# Processing Record 10 of Set 10 | guiratinga
# Processing Record 11 of Set 10 | kribi
# Processing Record 12 of Set 10 | kodiak
# Processing Record 13 of Set 10 | port hedland
# Processing Record 14 of Set 10 | nantucket
# Processing Record 15 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 16 of Set 10 | xining
# Processing Record 17 of Set 10 | clearwater
# Processing Record 18 of Set 10 | coquimbo
# Processing Record 19 of Set 10 | bonthe
# Processing Record 20 of Set 10 | mwinilunga
# Processing Record 21 of Set 10 | palauig
# Processing Record 22 of Set 10 | ardakan
# Processing Record 23 of Set 10 | hirara
# Processing Record 24 of Set 10 | sayyan
# Processing Record 25 of Set 10 | salinas
# Processing Record 26 of Set 10 | santa maria
# Processing Record 27 of Set 10 | sardhana
# Processing Record 28 of Set 10 | dondo
# Processing Record 29 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 10 | hami
# Processing Record 31 of Set 10 | san pedro
# Processing Record 32 of Set 10 | antalaha
# Processing Record 33 of Set 10 | nikolayevsk-na-amure
# Processing Record 34 of Set 10 | moissac
# Processing Record 35 of Set 10 | vilcun
# Processing Record 36 of Set 10 | sur
# Processing Record 37 of Set 10 | hassleholm
# Processing Record 38 of Set 10 | moosomin
# Processing Record 39 of Set 10 | khvorostyanka
# Processing Record 40 of Set 10 | tecoanapa
# Processing Record 41 of Set 10 | el balyana
# City not found. Skipping...
# Processing Record 42 of Set 10 | glenwood springs
# Processing Record 43 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 10 | mandalgovi
# Processing Record 45 of Set 10 | vytegra
# Processing Record 46 of Set 10 | svetlaya
# Processing Record 47 of Set 10 | healdsburg
# Processing Record 48 of Set 10 | livingston
# Processing Record 49 of Set 10 | plymouth
# Processing Record 50 of Set 10 | riohacha
# Processing Record 1 of Set 11 | haines junction
# Processing Record 2 of Set 11 | aykhal
# Processing Record 3 of Set 11 | pavda
# City not found. Skipping...
# Processing Record 4 of Set 11 | karachi
# Processing Record 5 of Set 11 | porto walter
# Processing Record 6 of Set 11 | aklavik
# Processing Record 7 of Set 11 | saint-augustin
# Processing Record 8 of Set 11 | riyadh
# Processing Record 9 of Set 11 | miraflores
# Processing Record 10 of Set 11 | rajshahi
# Processing Record 11 of Set 11 | totana
# Processing Record 12 of Set 11 | vanavara
# Processing Record 13 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 11 | zaozerne
# Processing Record 15 of Set 11 | santa rosa
# Processing Record 16 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 11 | las margaritas
# Processing Record 18 of Set 11 | the valley
# Processing Record 19 of Set 11 | vandra
# Processing Record 20 of Set 11 | tromso
# Processing Record 21 of Set 11 | dubrovka
# Processing Record 22 of Set 11 | okhotsk
# Processing Record 23 of Set 11 | bardiyah
# Processing Record 24 of Set 11 | payo
# Processing Record 25 of Set 11 | holme
# Processing Record 26 of Set 11 | galabovo
# Processing Record 27 of Set 11 | rybnaya sloboda
# Processing Record 28 of Set 11 | pombia
# Processing Record 29 of Set 11 | narsaq
# Processing Record 30 of Set 11 | san felipe
# Processing Record 31 of Set 11 | uyuni
# Processing Record 32 of Set 11 | quelimane
# Processing Record 33 of Set 11 | tanjong sepat
# City not found. Skipping...
# Processing Record 34 of Set 11 | encs
# Processing Record 35 of Set 11 | bahia honda
# Processing Record 36 of Set 11 | krasnoselkup
# Processing Record 37 of Set 11 | saint-joseph
# Processing Record 38 of Set 11 | bowen
# Processing Record 39 of Set 11 | katherine
# Processing Record 40 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 11 | samana
# Processing Record 42 of Set 11 | portland
# Processing Record 43 of Set 11 | ulladulla
# Processing Record 44 of Set 11 | moron
# Processing Record 45 of Set 11 | monrovia
# Processing Record 46 of Set 11 | douglas
# Processing Record 47 of Set 11 | dali
# Processing Record 48 of Set 11 | ayan
# Processing Record 49 of Set 11 | chumikan
# Processing Record 50 of Set 11 | broome
# Processing Record 1 of Set 12 | natal
# Processing Record 2 of Set 12 | tazmalt
# Processing Record 3 of Set 12 | xaxim
# Processing Record 4 of Set 12 | ornskoldsvik
# Processing Record 5 of Set 12 | iwanai
# Processing Record 6 of Set 12 | presidencia roque saenz pena
# Processing Record 7 of Set 12 | mulege
# Processing Record 8 of Set 12 | nuuk
# Processing Record 9 of Set 12 | agadez
# Processing Record 10 of Set 12 | castro
# Processing Record 11 of Set 12 | husavik
# Processing Record 12 of Set 12 | honiara
# Processing Record 13 of Set 12 | kungurtug
# Processing Record 14 of Set 12 | solaro
# Processing Record 15 of Set 12 | ustye
# Processing Record 16 of Set 12 | lorengau
# Processing Record 17 of Set 12 | krosno
# Processing Record 18 of Set 12 | okha
# Processing Record 19 of Set 12 | oskarshamn
# Processing Record 20 of Set 12 | mamallapuram
# Processing Record 21 of Set 12 | aktau
# Processing Record 22 of Set 12 | saint-pacome
# City not found. Skipping...
# Processing Record 23 of Set 12 | puerto baquerizo moreno
# Processing Record 24 of Set 12 | kiunga
# Processing Record 25 of Set 12 | kabala
# Processing Record 26 of Set 12 | huarmey
# Processing Record 27 of Set 12 | key west
# Processing Record 28 of Set 12 | flinders
# Processing Record 29 of Set 12 | alpena
# Processing Record 30 of Set 12 | prainha
# Processing Record 31 of Set 12 | puerto madryn
# Processing Record 32 of Set 12 | tome
# Processing Record 33 of Set 12 | velingrad
# Processing Record 34 of Set 12 | kharp
# Processing Record 35 of Set 12 | palafrugell
# Processing Record 36 of Set 12 | nizhnevartovsk
# Processing Record 37 of Set 12 | los andes
# Processing Record 38 of Set 12 | chimbote
# Processing Record 39 of Set 12 | north marysville
# City not found. Skipping...
# Processing Record 40 of Set 12 | loubomo
# Processing Record 41 of Set 12 | sayat
# Processing Record 42 of Set 12 | manta
# Processing Record 43 of Set 12 | tambura
# Processing Record 44 of Set 12 | bulgan
# Processing Record 45 of Set 12 | melekhovskaya
# City not found. Skipping...
# Processing Record 46 of Set 12 | paulo afonso
# Processing Record 47 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 49 of Set 12 | moyale
# Processing Record 50 of Set 12 | zhanakorgan
# Processing Record 1 of Set 13 | parambu
# Processing Record 2 of Set 13 | mazulskiy
# City not found. Skipping...
# Processing Record 3 of Set 13 | pleszew
# Processing Record 4 of Set 13 | tyukhtet
# Processing Record 5 of Set 13 | marietta
# Processing Record 6 of Set 13 | vestmannaeyjar
# Processing Record 7 of Set 13 | hafizabad
# Processing Record 8 of Set 13 | pochutla
# Processing Record 9 of Set 13 | bjerkvik
# Processing Record 10 of Set 13 | zhengjiatun
# Processing Record 11 of Set 13 | srednekolymsk
# Processing Record 12 of Set 13 | zhuanghe
# Processing Record 13 of Set 13 | batagay-alyta
# Processing Record 14 of Set 13 | tomatlan
# Processing Record 15 of Set 13 | isiro
# Processing Record 16 of Set 13 | aleksinac
# Processing Record 17 of Set 13 | huron
# Processing Record 18 of Set 13 | cabatuan
# Processing Record 19 of Set 13 | khon buri
# Processing Record 20 of Set 13 | asfi
# Processing Record 21 of Set 13 | perico
# Processing Record 22 of Set 13 | yumen
# Processing Record 23 of Set 13 | mehamn
# Processing Record 24 of Set 13 | qui nhon
# Processing Record 25 of Set 13 | duki
# Processing Record 26 of Set 13 | biltine
# Processing Record 27 of Set 13 | fort nelson
# Processing Record 28 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 13 | itau de minas
# Processing Record 30 of Set 13 | price
# Processing Record 31 of Set 13 | looc
# Processing Record 32 of Set 13 | richards bay
# Processing Record 33 of Set 13 | aden
# Processing Record 34 of Set 13 | wajid
# Processing Record 35 of Set 13 | shillong
# Processing Record 36 of Set 13 | benjamin hill
# Processing Record 37 of Set 13 | soyo
# Processing Record 38 of Set 13 | maceio
# Processing Record 39 of Set 13 | kjollefjord
# Processing Record 40 of Set 13 | dalby
# Processing Record 41 of Set 13 | lima
# Processing Record 42 of Set 13 | muyezerskiy
# Processing Record 43 of Set 13 | gravdal
# Processing Record 44 of Set 13 | mudgee
# Processing Record 45 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 13 | camacha
# Processing Record 47 of Set 13 | say
# Processing Record 48 of Set 13 | whitehorse
# Processing Record 49 of Set 13 | vysha
# Processing Record 50 of Set 13 | fukue
# Processing Record 1 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 2 of Set 14 | mar del plata
# Processing Record 3 of Set 14 | kloulklubed
# Processing Record 4 of Set 14 | sao joao da barra
# Processing Record 5 of Set 14 | puerto montt
# Processing Record 6 of Set 14 | broken hill
# Processing Record 7 of Set 14 | valley city
# Processing Record 8 of Set 14 | inhambane
# Processing Record 9 of Set 14 | senanga
# Processing Record 10 of Set 14 | kununurra
# Processing Record 11 of Set 14 | vangaindrano
# Processing Record 12 of Set 14 | panguna
# Processing Record 13 of Set 14 | alcacer do sal
# Processing Record 14 of Set 14 | pimenta bueno
# Processing Record 15 of Set 14 | salta
# Processing Record 16 of Set 14 | ashtian
# Processing Record 17 of Set 14 | urman
# Processing Record 18 of Set 14 | tulsipur
# Processing Record 19 of Set 14 | sabzevar
# Processing Record 20 of Set 14 | ifanadiana
# Processing Record 21 of Set 14 | naron
# Processing Record 22 of Set 14 | linqiong
# Processing Record 23 of Set 14 | pavilosta
# Processing Record 24 of Set 14 | bocana de paiwas
# Processing Record 25 of Set 14 | lanzhou
# Processing Record 26 of Set 14 | naryan-mar
# Processing Record 27 of Set 14 | yanam
# Processing Record 28 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 29 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 14 | kapit
# Processing Record 31 of Set 14 | mega
# Processing Record 32 of Set 14 | oytal
# Processing Record 33 of Set 14 | lianyuan
# Processing Record 34 of Set 14 | honningsvag
# Processing Record 35 of Set 14 | launceston
# Processing Record 36 of Set 14 | teya
# Processing Record 37 of Set 14 | andenes
# Processing Record 38 of Set 14 | morant bay
# Processing Record 39 of Set 14 | pacifica
# Processing Record 40 of Set 14 | cockburn town
# Processing Record 41 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 14 | alyangula
# Processing Record 43 of Set 14 | turukhansk
# Processing Record 44 of Set 14 | chapleau
# Processing Record 45 of Set 14 | skjervoy
# Processing Record 46 of Set 14 | makakilo city
# Processing Record 47 of Set 14 | gat
# Processing Record 48 of Set 14 | petauke
# Processing Record 49 of Set 14 | bolshevik
# Processing Record 50 of Set 14 | lakselv
# Processing Record 1 of Set 15 | inverell
# Processing Record 2 of Set 15 | college
# Processing Record 3 of Set 15 | boone
# Processing Record 4 of Set 15 | najran
# Processing Record 5 of Set 15 | auki
# Processing Record 6 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 7 of Set 15 | gazli
# Processing Record 8 of Set 15 | saldanha
# Processing Record 9 of Set 15 | krasnoborsk
# Processing Record 10 of Set 15 | barranca
# Processing Record 11 of Set 15 | mount darwin
# Processing Record 12 of Set 15 | basoko
# Processing Record 13 of Set 15 | pangody
# Processing Record 14 of Set 15 | arman
# Processing Record 15 of Set 15 | longkou
# Processing Record 16 of Set 15 | ouricuri
# Processing Record 17 of Set 15 | comodoro rivadavia
# Processing Record 18 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 19 of Set 15 | sambulawan
# Processing Record 20 of Set 15 | biak
# Processing Record 21 of Set 15 | mananjary
# Processing Record 22 of Set 15 | siuna
# Processing Record 23 of Set 15 | vila
# Processing Record 24 of Set 15 | riachao das neves
# Processing Record 25 of Set 15 | jumla
# Processing Record 26 of Set 15 | kurchum
# Processing Record 27 of Set 15 | trinidad
# Processing Record 28 of Set 15 | ziguinchor
# Processing Record 29 of Set 15 | joshimath
# Processing Record 30 of Set 15 | abnub
# Processing Record 31 of Set 15 | faya
# Processing Record 32 of Set 15 | matagami
# Processing Record 33 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 15 | chifeng
# Processing Record 35 of Set 15 | vao
# Processing Record 36 of Set 15 | luderitz
# Processing Record 37 of Set 15 | northam
# Processing Record 38 of Set 15 | siloam springs
# Processing Record 39 of Set 15 | boende
# Processing Record 40 of Set 15 | gigmoto
# Processing Record 41 of Set 15 | fort-shevchenko
# Processing Record 42 of Set 15 | ginir
# Processing Record 43 of Set 15 | wilmington island
# Processing Record 44 of Set 15 | calbuco
# Processing Record 45 of Set 15 | suntar
# Processing Record 46 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 15 | beira
# Processing Record 48 of Set 15 | hays
# Processing Record 49 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 50 of Set 15 | san andres
# Processing Record 1 of Set 16 | mtsamboro
# Processing Record 2 of Set 16 | jalu
# Processing Record 3 of Set 16 | villamontes
# Processing Record 4 of Set 16 | port hardy
# Processing Record 5 of Set 16 | lethem
# Processing Record 6 of Set 16 | dzilam gonzalez
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 691

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Mataura      NZ -46.1927  168.8643     50.49        84          13
# 1    Manjacaze      MZ -24.7117   33.8828     70.90        96          25
# 2       Albany      US  42.6001  -73.9662     66.24        34         100
# 3      Ushuaia      AR -54.8000  -68.3000     42.42        68         100
# 4  Clyde River      CA  70.4692  -68.5914      8.83        85         100
# 5         Lebu      CL -37.6167  -73.6500     56.46        68         100
# 6       Hasaki      JP  35.7333  140.8333     59.40        89          98
# 7    Tuatapere      NZ -46.1333  167.6833     43.57        84          25
# 8       Hobart      AU -42.8794  147.3294     52.05        90          73
# 9  New Norfolk      AU -42.7826  147.0587     51.71        85          73
#
#    Wind Speed Current Description
# 0        6.11          few clouds
# 1        5.19    scattered clouds
# 2        5.99     overcast clouds
# 3        3.51     overcast clouds
# 4       25.32          light snow
# 5       20.33     overcast clouds
# 6        6.06     overcast clouds
# 7        6.78    scattered clouds
# 8        5.75       broken clouds
# 9        2.39       broken clouds

# %%
## Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
